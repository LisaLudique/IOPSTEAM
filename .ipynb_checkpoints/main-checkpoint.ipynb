# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
% matplotlib inline

# %%
# Removed un-needed columns from original dataset, use data
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    FIO_ID   SEX  STREET_ID  DIST_ID PRIORS  \
# 0  621880  MALE       3274        3    YES
# 1  565177  MALE        543        1     NO
# 2  565340  MALE       4493        5    YES
# 3  653895  MALE       3094        3    YES
# 4  566043  MALE       4241        3    YES
#
#                                           CLOTHING COMPLEXION FIOFS_TYPE  \
# 0  blk jacket, blk shirt, blue jeans, wht sneakers        Med       IOFS
# 1                      GRY. SWEATSHIRT, BLUE JEANS        Med         IO
# 2                        GRY SWEATSHIRT, GRY PANTS       Dark        IOF
# 3                     lime green shirt, blue jeans        Med       IOFS
# 4                          BLU DOWN VEST BLU PANTS      Light         IO
#
#   TERRORISM SEARCH         ...                 VEH_COLOR VEH_MODEL  \
# 0        NO     VP         ...                    SILVER       max
# 1        NO    NaN         ...           NO DATA ENTERED       NaN
# 2        NO    NaN         ...           NO DATA ENTERED       NaN
# 3        NO    NaN         ...           NO DATA ENTERED       NaN
# 4        NO      P         ...                       RED       2DR
#
#   VEH_OCCUPANT SUPERVISOR_ID OFFICER_ID OFF_DIST_ID  ETHNICITY RACE_ID  \
# 0       DRIVER       10132.0      98656        9999        NaN       2
# 1          NaN        8949.0       9765           1        NaN       4
# 2          NaN       11312.0      83575          16        NaN       2
# 3          NaN        9375.0      76146          25        NaN       2
# 4          NaN           NaN     107106           3        NaN       2
#
#        FIO_DATE_CORRECTED AGE_AT_FIO_CORRECTED
# 0  12/10/2013 12:00:00 AM                   59
# 1  05/24/2012 12:00:00 AM                   26
# 2  06/04/2012 12:00:00 AM                   18
# 3  06/21/2014 12:00:00 AM                   24
# 4  12/02/2011 12:00:00 AM                   70
#
# [5 rows x 27 columns]

# %%
outcome = data["OUTCOME"]

# %%
"""
TODOs:

Ignore (for now):
-FIO_ID
-Supervisor, officer ID (and officer district ID)

Convert to numbers:
-SEX
-PRIORS
-COMPLEXION
-FIOFS_TYPE
-TERRORISM
-SEARCH
-BASIS
-STOP_REASONS
-FIOFS_REASONS
-ETHNICITY

One-hot-encode + clean:
-CLOTHING
-VEHICLE
"""
