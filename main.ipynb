# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
% matplotlib inline

# %%
data = pd.read_csv("Boston_Police_Department_FIO.csv")

# %%
data.head()
# Out:
#    SEQ_NUM  FIO_ID   SEX                   LOCATION DIST  DIST_ID  \
# 0   938283  621880  MALE   NORMANDY ST at SUPPLE RD   B2        3
# 1   881897  565177  MALE             75 BOYLSTON ST   A1        1
# 2   882060  565340  MALE               5 TOPLIFF ST  C11        5
# 3   971623  653895  MALE              170 MORTON ST   B2        3
# 4   882761  566043  MALE          0 ST ALPHONSUS ST   B2        3
#
#         FIO_DATE       FIO_TIME PRIORS DESCRIPTION       ...         \
# 0  12/10/13 0:00  12/10/13 0:00    YES    B(Black)       ...
# 1   5/24/12 0:00   5/24/12 0:00     NO    W(White)       ...
# 2    6/4/12 0:00    6/4/12 0:00    YES    B(Black)       ...
# 3   6/21/14 0:00   6/21/14 0:00    YES    B(Black)       ...
# 4   12/2/10 0:00   12/2/10 0:00    YES    B(Black)       ...
#
#   OFF_DIST_ID OFF_DIST              OFFICER ETHNICITY FIRST_INSERTTIME  \
# 0        9999    OTHER       Liam P Hawkins       NaN     1/30/14 0:00
# ...

# %%
outcome = data["TERRORISM"]
for row in outcome:
    if row == "YES":
        print yes
print outcome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1c16b18c447a> in <module>()
#       2 for row in outcome:
#       3     if row == "YES":
# ----> 4         print yes
#       5 print outcome
#
# NameError: name 'yes' is not defined
